# %% [markdown]
# # 🤝 使用 GitHub 模型的多智能体工作流系统 (Python)
#
# ## 📋 学习目标
#
# 本笔记本展示了如何使用 Microsoft Agent Framework 和 GitHub 模型构建复杂的多智能体系统。您将学习如何通过结构化工作流程编排多个专业智能体协同工作来解决复杂问题。
#
# **您将构建的多智能体功能：**
# - 👥 **智能体协作**：多个智能体为共同目标而合作
# - 🔄 **工作流编排**：智能体交互的结构化协调
# - 🎭 **角色专业化**：具有不同个性和专业领域的智能体
# - 📋 **质量保证**：通过智能体协作进行审查和改进
#
# ## 🎯 多智能体架构概念
#
# ### 核心多智能体原则
# - **分工合作**：每个智能体专门负责特定领域的专业知识
# - **协作决策**：智能体审查和改进彼此的工作
# - **工作流协调**：结构化的交接和沟通模式
# - **质量提升**：通过多视角分析进行迭代改进
#
# ### 智能体交互模式
# - **顺序处理**：线性工作流，智能体有序参与
# - **同行评审**：智能体验证和改进彼此的输出
# - **层次结构**：主导智能体协调专业下属
# - **共识构建**：多个智能体为最终决策做出贡献
#
# ## 🏗️ 技术架构
#
# ### 工作流系统组件
# - **Microsoft Agent Framework**：具有高级工作流支持的 Python 实现
# - **WorkflowBuilder**：声明式工作流定义和执行引擎
# - **智能体协调**：结构化的通信和交接机制
# - **事件驱动处理**：基于智能体输出的响应式工作流执行
#
# ### 多智能体流程
# ```python
# 用户请求 → 智能体 1（专家）→ 智能体 2（评审员）→ 质量检查
#                 ↓                      ↓                    ↓
#          初始解决方案 → 评审与反馈 → 改进输出 → 最终结果
# ```
#
# ## 🎭 智能体角色示例
#
# ### 酒店礼宾系统
# 本笔记本展示了一个具有专业角色的旅行推荐系统：
#
# #### 🏨 **前台智能体**
# - **专业知识**：旅行推荐和本地知识
# - **个性**：高效、经验丰富、简洁的沟通风格
# - **职责**：生成初始旅行建议和活动
#
# #### 🎩 **礼宾智能体**
# - **专业知识**：真实的本地体验和质量评估
# - **个性**：有洞察力，专注于非旅游景点的推荐
# - **职责**：审查和改进旅行建议，确保真实性
#
# ## 🔧 技术实现
#
# ### 工作流架构
# - **智能体定义**：专业指令和个性配置
# - **工作流构建器**：具有事件处理的声明式工作流定义
# - **通信协议**：智能体之间的结构化消息传递
# - **结果聚合**：结合多个智能体视角的输出
#
# ### 事件驱动协调
# - **WorkflowEvent**：智能体激活和交接的触发点
# - **OutputEvent**：智能体之间的结构化数据交换
# - **质量关卡**：工作流过程中的验证检查点
# - **反馈循环**：通过智能体协作进行迭代改进
#
# ## ⚙️ 先决条件与设置
#
#
# **所需依赖项：**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **环境配置 (.env 文件)：**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 多智能体设计模式
#
# ### 1. **生产者-消费者模式**
# - 专业智能体生成内容供其他智能体审查
# - 明确的交接点和数据交换协议
# - 通过独立审查确保质量
# - 迭代改进和完善周期
#
# ### 2. **委员会模式**
# - 多个智能体贡献不同的视角
# - 通过结构化讨论建立共识
# - 具有加权意见的民主决策
# - 冲突解决和打破平局机制
#
# ### 3. **层次模式**
# - 主导智能体协调专业下属
# - 明确的权限结构和决策流程
# - 复杂决策的升级路径
# - 绩效监控和质量控制
#
# ### 4. **管道模式**
# - 具有专业阶段的顺序处理
# - 每个智能体在其专业领域增加价值
# - 通过并行处理实现高效吞吐量
# - 每个阶段的错误处理和恢复
#
# ## 🚀 高级多智能体功能
#
# ### 工作流编排
# - **动态路由**：基于上下文的智能体选择和路由
# - **并行处理**：为提高效率而并发执行智能体
# - **错误恢复**：智能体故障的优雅处理和重试
# - **性能监控**：跟踪工作流执行和优化
#
# ### 智能体通信
# - **结构化消息传递**：类型安全的通信协议
# - **上下文保留**：在智能体之间维护对话历史
# - **元数据传递**：超越文本内容的丰富信息交换
# - **事件广播**：用于协调的发布-订阅模式
#
# ### 质量保证
# - **多视角审查**：不同智能体带来独特视角
# - **迭代改进**：通过协作逐步改进
# - **验证检查点**：工作流中的质量关卡
# - **性能指标**：衡量协作有效性
#
# ## 📊 用例与应用
#
# ### 业务流程自动化
# - 文档审查和批准工作流
# - 客户服务升级系统
# - 质量保证和合规检查
# - 多阶段内容创建和编辑
#
# ### 研究与分析
# - 研究论文的同行评审系统
# - 多分析师财务分析
# - 协作报告撰写和事实检查
# - 学术论文审查和改进
#
# ### 创意协作
# - 编辑和评审的内容创建
# - 多视角创意头脑风暴
# - 迭代设计和反馈系统
# - 协作讲故事和世界构建
#
# 准备好编排智能多智能体协作了吗？让我们构建智能体像高绩效团队一样协同工作的系统！ 🌟🤖

# %%
! pip install agent-framework-core -U

# %%
# 🤖 导入多智能体工作流组件
# OpenAIChatClient: GitHub 模型集成，用于智能体通信
# WorkflowEvent, WorkflowBuilder: 核心工作流编排类
# WorkflowOutputEvent: 用于智能体协调的结构化事件处理
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent

# %%
# 📦 导入配置和环境管理
import os                      # 环境变量访问，用于安全配置
from dotenv import load_dotenv # 安全加载 API 凭证和设置

# %%
# 🔧 加载多智能体工作流配置  
# 加载环境变量以安全访问 GitHub 模型
# 必需：GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID 用于智能体通信
load_dotenv()
# Out:
# True

# %%
# 🔗 初始化多智能体通信的共享聊天客户端
# 创建一个统一的客户端，工作流中的所有智能体将使用它
# 这确保了一致的 API 访问和高效的资源利用
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub 模型 API 端点
    api_key=os.environ.get("GITHUB_TOKEN"),        # 认证令牌
    model_id=os.environ.get("GITHUB_MODEL_ID")  # 工作流中所有智能体使用的模型
)

# %%
# 🎩 智能体 1: 酒店礼宾 - 质量评审角色
# 该智能体专门评估旅行推荐的真实性
# 在我们的多智能体工作流中作为第二阶段，负责质量保证
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# Workflow output: Visit the Louvre Museum for an unparalleled art experience.
